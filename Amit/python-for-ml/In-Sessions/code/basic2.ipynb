# %%
#list
list_one=[1,2,3,"ma","learn",[1,2,"mn"],True]
list_one[5][1]="data"
list_one[5][1]
list_one.append("mariam")
list_one.insert(1,"depi")
list_2=[4,5,6]
list_one.extend(list_2)
list_one.remove("mariam")
list_one.pop()
del list_one

# %%
list_1=[1,2,3]
list_2=[1,2,3]
list_3=[1,2,3]
matrix=[list_1,list_2,list_3]
matrix
# Out:
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
my_list=[1,2,3,4]
my_list[:2]
#repate list
my_list*2
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
#input function
name=input('enter your name')
name
# Out:
# 'marriam'

# %%
input_list=["depi","learing","python"]

# %%
my_list=[1,2,3,2,3,4,5,7]
index_val=my_list.index(3)
index_val
count=my_list.count(2)
count
m
# Out:
# 2

# %%
#tuple

# %%
#set
set_1={"depi","learing","depi","machine learing"}
set_2={"depi","machine","depi"}
set_1.discard("depi")
print(set_1.difference(set_2))
# Out:
# {'learing', 'machine learing'}

# %%
#dictionary 
dict_1={"age":25}
type(dict_1)
dict_1["course"]="machine"
dict_1
# Out:
# {'age': 25, 'course': 'machine'}

# %%
#operation
5//2#return interger
5%2#return remine of division
# Out:
# 1

# %%
#logical
# ->>>> and or not 

#identity
# is  --  is not

# %%
num1=float(input('enter num1 :'))
num2=float(input('enter num2 :'))
print(f'sumation of :{num1} + {num2} = {num1+num2}')
print(f'subtraction of :{num1} - {num2} = {num1-num2}')
print(f'mulitply of :{num1} * {num2} = {num1*num2}')
print(f'division of :{num1} / {num2} = {num1/num2}')
# Out:
# sumation of :6.0 + 2.0 = 8.0
# subtraction of :6.0 - 2.0 = 4.0
# mulitply of :6.0 * 2.0 = 12.0
# division of :6.0 / 2.0 = 3.0

# %%
#if-condition 
a=200
b=33
if a<b:
   print("b is grater than a")
elif a==b:
   print("a is equal b")
else:
   print("a is grater than b")

################################
x=4
y=10
if (x>0 and y>0):
   print("positive numbers")

################################
x=4
res="Even" if x%2==0 else "odd"
print(res)
# Out:
# a is grater than b
# positive numbers
# Even

# %%
a=10
b=5
res=a+b if a>b else a-b
print(res)
# Out:
# 15

# %%
age =21
print("adult") if age >=18 else (print("Teenager")  if age <18 print("Child"))
# Out:
#   Cell In[79], line 2
#     print("adult") if age >=18 else (print("Teenager")  elif age <18 print("Child"))
#                                                         ^
# SyntaxError: invalid syntax

# %%
is_sunny=True
tem =25
if is_sunny:
   print("sunny day")
   if tem>20:
      print("warm")
   else:
      print("cool")
else:
   print("not sunny")
# Out:
# sunny day
# warm

# %%
grade=int(input("enter your grade"))

if 0<=grade<=100:
   if 90<=grade<=100:
      grade='A'
   elif 80<=grade<=90:
      grade="B"   


else:
   print("enter value between 0-100")      

grade

# %%
for i in range(6):
   if i==3:
      pass
   else:
      print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
#while
x=6
while x>0:
   print("python")
   x -=1
# Out:
# python
# python
# python
# python
# python
# python

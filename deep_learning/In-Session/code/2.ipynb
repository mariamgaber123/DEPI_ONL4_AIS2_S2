# %%
pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/350.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/350.9 MB ? eta -:--:--
# ...

# %%
import tensorflow as tf

# %%
x = tf.constant([[5,2],[1,3]])
print(x)
# Out:
# tf.Tensor(
# [[5 2]
#  [1 3]], shape=(2, 2), dtype=int32)

# %%
tf.random.normal(shape=(2,2),mean=0,stddev=1.)

# %%
init_val = tf.random.normal(shape=(2,2))
a = tf.Variable(init_val)
print(a)

# %%
a = tf.random.normal(shape=(2,2))
b = tf.random.normal(shape=(2,2))
c = a + b
print(c)
d = tf.square(c)
print(d)

# %%
with tf.GradientTape

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('D:\DEPI\Amit\Amit\deep_learning\In-Session\data_sets\FuelConsumptionCo2.csv')

# %%
x_d = data.iloc[:,''].values
y_d = data.iloc[:,''].values
#wx + b = y

# %%
x = tf.constant(x_d,dtype='float32')
y = tf.constant(y_d,dtype='float32')

# %%
w = tf.Variable(2.0,dtype='float32')
b = tf.Variable(7.2,dtype='float32')

# %%
def H(x):
   y_p = w*x +b
   return y_p

# %%
def cost_function(y_actual,y_pred):
    mse = tf.reduce_mean(tf.square(y_actual,y_pred))
    return mse

# %%
lr =0.01
epochs = 1000
losses_values = []
for epoch in epochs:
   y_pred = cost_function(y,y_pred)
   losses_values =

# %%
#reverse word
def reverse_words(s):
   l = s.split()
   l.reverse()
   s = " ".join(l)
   return s

# %%
#problem2
def playJ(name):
   if name[0] =='R' or name[0]=='r' :
      return f"{name} plays banjo" 
   else:
      return f"{name} does not play banjo"


playJ("an")
# Out:
# 'an does not play banjo'

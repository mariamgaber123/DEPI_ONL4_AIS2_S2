# %%
print("Hello")
# Out:
# Hello

# %%
x =30 #this init variable

''' 

'''

print("""my "age is""",x)
# Out:
# my "age is 30

# %%
name ="depi"
age=30
print("my name is {} and my age is {}".format(name,age))
# Out:
# my name is depi and my age is 30
# my name is depi and my age is 30

# %%
#quiz
name="mariam"
age=20
course_name="machine learning"
print(f"my name is {name} ,and I am {age} years old.i am engaged in learing {course_name}")
# Out:
# my name is mariam ,and I am 20 years old.i am engaged in learing machine learing

# %%
#data type
x = "44"
print(type(x))
# Out:
# <class 'str'>

# %%
#string 
s="depi learning for machine learning"
print(s.index('e'))
print(s[0:3])
print(s.upper())
print(s.capitalize())
print(s.replace("depi","amit"))
print(s.count("e"))
x=s.split() 
print(type(x))
response=' '.join(x)
response
response.startswith('d')
# Out:
# 1
# dep
# DEPI LEARNING FOR MACHINE LEARNING
# Depi learning for machine learning
# amit learning for machine learning
# 4
# <class 'list'>
# True

# %%
#Escape Characters
print("hello\nworld")
print("hello \"world\"")
print("hello \tworld")
print("hello world")
# Out:
# hello
# world
# hello "world"
# hello	world

# %%
x=2
X=2
print(hex(id(x)))
print(id(X))
# Out:
# 0x7ffdb303e9d8
# 140727606831576

# %%
#list
x=[1,2,3,"depi",3.5,True,["mariam","gaber","farg"]]
type(x)
name="mariam"
l=list(name)
l.reverse()
l
# Out:
# ['m', 'a', 'i', 'r', 'a', 'm']

# %%
#tuple
x=(1,2,3,"depi",3.5,True,["mariam","gaber","farg"])
type(x)
# Out:
# tuple

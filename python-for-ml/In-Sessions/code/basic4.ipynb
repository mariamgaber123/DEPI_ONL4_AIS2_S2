# %% [markdown]
# # File Handling

# %%
#file handling 
with open("./files/text_1.txt","a+") as file: #W  #R
     
     # content = file.read()

     file.write(" New line addad\n")  # Write new content

     file.seek(0)   # Move the file pointer to the beginning

     update_content=file.read() # Read the updated content
     
     print(update_content)
# Out:
#  New line addad
#  New line addad

# %%
f = open("text_1.txt","a")
f.write("Hello\n")
f.close()

f=open("text_1.txt","r")
read_file=f.read()
print(read_file)
f.close()
# Out:
# Hello
